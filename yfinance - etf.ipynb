# %%
import yfinance as yf

# %%
import yfinance as yf
import pandas as pd

# Replace with your list of ETF tickers
tickers = ["QDVO", "BALI", "JEPI","QQQI","GPIX","SPYI","GPIQ","JEPQ"]  # example

records = []

for symbol in tickers:
    print(f"Getting {symbol}")
    etf = yf.Ticker(symbol)
    info = etf.info
    name=info.get("longName")
    print(name)

    # Core metrics
    pe = info.get("trailingPE")
    expense_ratio = info.get("netExpenseRatio")
    category = info.get("category")
    currency = info.get("currency")
    sector = info.get("sector")
    market_cap = info.get("marketCap")
    managing_company = info.get("fundFamily") or profile.get("fundFamily")
    nav_price = info.get("navPrice")
    div_yield = info.get('dividendYield')

    # # Dividend yield: actual or synthetic
    # div_yield = info.get("dividendYield") or info.get("trailingAnnualDividendYield") or 0
    # if not div_yield and not top_holdings.empty:
    #     synthetic = 0.0
    #     for row in top_holdings.itertuples():
    #         weight_frac = getattr(row, 'weight', 0) / 100.0
    #         dy = yf.Ticker(getattr(row, 'symbol', None)).info.get("dividendYield") or 0
    #         synthetic += weight_frac * dy
    #     div_yield = synthetic

    # Top 3 holdings and weights
    tops = etf.funds_data.top_holdings
    top1 = tops.iloc[0]["Name"]
    top1weight = float(tops.iloc[0]["Holding Percent"])
    top1pe = yf.Ticker(tops.index[0]).info["trailingPE"]
    top2 = tops.iloc[1]["Name"]
    top2weight = float(tops.iloc[1]["Holding Percent"])
    top3 = tops.iloc[2]["Name"]
    top3weight = float(tops.iloc[2]["Holding Percent"])
    # Price data
    hist = etf.history(period="1y")
    current_price = hist['Close'].iloc[-1] if not hist.empty else None
    price_12m_ago = hist['Close'].iloc[0] if not hist.empty else None

    # Strategy / Thesis
    thesis = info.get("longBusinessSummary")

    records.append({
        "Ticker": symbol,
        "Name": name,
        "Currency": currency,
        "PE": pe,
        "Expense Ratio": expense_ratio,
        "Category": category,
        "Sector": sector,
        "Market Cap": market_cap,
        "Managing Company": managing_company,
        "Dividend Yield (%)": div_yield if div_yield is not None else None,
        "Top 1 Holding": top1,
        "Weight 1": top1weight,
        "Top 1 P/E": top1pe,
        "Top 2 Holding": top2,
        "Weight 2": top2weight,
        "Top 3 Holding": top3,
        "Weight 3": top3weight,
        # "Top Holding 1": symbols[0] if len(symbols) > 0 else None,
        # "Weight 1 (%)": weights[0] if len(weights) > 0 else None,
        # "Top Holding 2": symbols[1] if len(symbols) > 1 else None,
        # "Weight 2 (%)": weights[1] if len(weights) > 1 else None,
        # "Top Holding 3": symbols[2] if len(symbols) > 2 else None,
        # "Weight 3 (%)": weights[2] if len(weights) > 2 else None,
        "Current Price": current_price,
        "Nav Price": nav_price,
        "Price 12 Months Ago": price_12m_ago,
        "Strategy": thesis
    })

# Build DataFrame and 
df = pd.DataFrame(records)
df.head(50)
# export to CSV
# df.to_csv("C:/Users/julia/Downloads/etf_summary.csv", index=False)
# print("Exported ETF summary to etf_summary.csv")
# Out:
# Getting QDVO
# Amplify CWP Growth & Income ETF
# Getting BALI
# iShares Advantage Large Cap Income ETF
# Getting JEPI
# JPMorgan Equity Premium Income ETF
# Getting QQQI
# NEOS NASDAQ-100(R) High Income ETF
# Getting GPIX
# Goldman Sachs S&P 500 Premium Income ETF
#tops.reset_index
#float(tops.iloc[0]["Holding Percent"])
#tops.reset_index
#tops.index[0]
# Out:
# {'phone': '(800) 480-4111',
#  'longBusinessSummary': 'The fund seeks to achieve this objective by (1) creating an actively managed portfolio of equity securities comprised significantly of those included in the fund’s primary benchmark, the Nasdaq-100 Index® (the Benchmark), and (2) through equity-linked notes (ELNs), selling call options with exposure to the Benchmark. It is non-diversified.',
#  'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 54.03,
#  'open': 54.11,
#  'dayLow': 54.06,
#  'dayHigh': 54.2,
#  'regularMarketPreviousClose': 54.03,
#  'regularMarketOpen': 54.11,
#  'regularMarketDayLow': 54.06,
#  'regularMarketDayHigh': 54.2,
#  'trailingPE': 31.22552,
#  'volume': 4139159,
#  'regularMarketVolume': 4139159,
#  'averageVolume': 6467006,
#  'averageVolume10days': 6890060,
#  'averageDailyVolume10Day': 6890060,
#  'bid': 54.13,
#  'ask': 54.18,
#  'bidSize': 1,
#  'askSize': 5,
#  'yield': 0.112799995,
#  'totalAssets': 26269374464,
#  'fiftyTwoWeekLow': 44.311,
#  'fiftyTwoWeekHigh': 58.54,
#  'fiftyDayAverage': 52.6138,
#  'twoHundredDayAverage': 54.459625,
#  'navPrice': 52.7922,
#  'currency': 'USD',
#  'tradeable': False,
#  'category': 'Derivative Income',
#  'ytdReturn': -2.88367,
#  'beta3Year': 0.83,
#  'fundFamily': 'JPMorgan',
#  'fundInceptionDate': 1651536000,
#  'legalType': 'Exchange Traded Fund',
#  'threeYearAverageReturn': 0.1559629,
#  'quoteType': 'ETF',
#  'symbol': 'JEPQ',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'ETF',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 1651671000000,
#  'preMarketChange': 0.034999847,
#  'preMarketChangePercent': 0.064634986,
#  'preMarketPrice': 54.185,
#  'regularMarketChange': 0.120003,
#  'regularMarketDayRange': '54.06 - 54.2',
#  'fullExchangeName': 'NasdaqGM',
#  'averageDailyVolume3Month': 6467006,
#  'fiftyTwoWeekLowChange': 9.839001,
#  'fiftyTwoWeekLowChangePercent': 0.2220442,
#  'fiftyTwoWeekRange': '44.311 - 58.54',
#  'fiftyTwoWeekHighChange': -4.3899994,
#  'fiftyTwoWeekHighChangePercent': -0.07499145,
#  'fiftyTwoWeekChangePercent': -3.4931362,
#  'dividendYield': 11.28,
#  'trailingThreeMonthReturns': -3.10852,
#  'trailingThreeMonthNavReturns': -3.10852,
#  'netAssets': 26269374500.0,
#  'epsTrailingTwelveMonths': 1.7341585,
#  'corporateActions': [],
#  'preMarketTime': 1752062814,
#  'regularMarketTime': 1752004801,
#  'fiftyDayAverageChange': 1.5362015,
#  'fiftyDayAverageChangePercent': 0.029197691,
#  'twoHundredDayAverageChange': -0.30962372,
#  'twoHundredDayAverageChangePercent': -0.005685381,
#  'netExpenseRatio': 0.35,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'cryptoTradeable': False,
#  'exchange': 'NGM',
#  'messageBoardId': 'finmb_1771574239',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 0.222104,
#  'regularMarketPrice': 54.15,
#  'shortName': 'JPMorgan Nasdaq Equity Premium ',
#  'longName': 'JPMorgan Nasdaq Equity Premium Income ETF',
#  'marketState': 'PRE',
#  'trailingPegRatio': None}

# %%
stock=yf.Ticker("AAPL")
stock.info["trailingPE"]
# Out:
# 30.901869
